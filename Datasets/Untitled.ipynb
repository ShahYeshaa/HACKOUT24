# %%
import pandas as pd

# %%
my_csv = pd.read_csv("https://catalog.ourworldindata.org/explorers/agriculture/latest/crop_yields/crop_yields.csv")
my_csv
# Out:
#            country  year  abaca__manila_hemp__raw_yield  \
# 0      Afghanistan  1961                            NaN
# 1      Afghanistan  1962                            NaN
# 2      Afghanistan  1963                            NaN
# 3      Afghanistan  1964                            NaN
# 4      Afghanistan  1965                            NaN
# ...            ...   ...                            ...
# 14572     Zimbabwe  2018                            NaN
# 14573     Zimbabwe  2019                            NaN
# 14574     Zimbabwe  2020                            NaN
# 14575     Zimbabwe  2021                            NaN
# 14576     Zimbabwe  2022                            NaN
#
#        agave_fibres__raw__n_e_c__yield  almond_yield  apples_yield  \
# 0                                  NaN           NaN        6.8018
# 1                                  NaN           NaN        6.8018
# 2                                  NaN           NaN        6.8018
# ...

# %%
my_csv
# Out:
#            country  year  abaca__manila_hemp__raw_yield  \
# 0      Afghanistan  1961                            NaN
# 1      Afghanistan  1962                            NaN
# 2      Afghanistan  1963                            NaN
# 3      Afghanistan  1964                            NaN
# 4      Afghanistan  1965                            NaN
# ...            ...   ...                            ...
# 14572     Zimbabwe  2018                            NaN
# 14573     Zimbabwe  2019                            NaN
# 14574     Zimbabwe  2020                            NaN
# 14575     Zimbabwe  2021                            NaN
# 14576     Zimbabwe  2022                            NaN
#
#        agave_fibres__raw__n_e_c__yield  almond_yield  apples_yield  \
# 0                                  NaN           NaN        6.8018
# 1                                  NaN           NaN        6.8018
# 2                                  NaN           NaN        6.8018
# ...

# %%
my_csv.to_csv('FAO_FoodDataSet.csv', index=False)

# %%
columns = my_csv.columns

# %%
for c in columns:
    print(c)
# Out:
# country
# year
# abaca__manila_hemp__raw_yield
# agave_fibres__raw__n_e_c__yield
# almond_yield
# apples_yield
# apricots_yield
# areca_nuts_yield
# artichokes_yield
# asparagus_yield
# avocados_yield
# bambara_beans__dry_yield
# banana_yield
# barley_yield
# bean_yield
# beans__green_yield
# blueberries_yield
# broad_beans_and_horse_beans__green_yield
# broad_beans_yield
# buckwheat_yield
# cabbages_yield
# canary_seed_yield
# carrots_and_turnips_yield
# cashew_nuts_yield
# cashewapple_yield
# cassava_leaves_yield
# cassava_yield
# castor_oil_seed_yield
# cauliflowers_and_broccoli_yield
# cereals_n_e_c__yield
# cereal_yield
# cherries_yield
# chestnut_yield
# chickpeas_yield
# chicory_roots_yield
# chillies_and_peppers__green__capsicum_spp__and_pimenta_spp__yield
# chillies_and_peppers_yield
# cinnamon_and_cinnamon_tree_flowers__raw_yield
# citrus_fruit_yield
# cloves__whole_stems__raw_yield
# cocoa_yield
# coconuts_yield
# coffee_yield
# cow_peas_yield
# cranberries_yield
# ...

# %%
crop_yields = [
    "almond_yield", "apples_yield", "apricots_yield", "areca_nuts_yield", 
    "artichokes_yield", "asparagus_yield", "avocados_yield", "bambara_beans__dry_yield", 
    "banana_yield", "barley_yield", "bean_yield", "beans__green_yield", 
    "blueberries_yield", "broad_beans_and_horse_beans__green_yield", "broad_beans_yield", 
    "buckwheat_yield", "cabbages_yield", "canary_seed_yield", "carrots_and_turnips_yield", 
    "cashew_nuts_yield", "cashewapple_yield", "cassava_leaves_yield", "cassava_yield", 
    "cauliflowers_and_broccoli_yield", "cereals_n_e_c__yield", "cereal_yield", 
    "cherries_yield", "chestnut_yield", "chickpeas_yield", "chicory_roots_yield", 
    "chillies_and_peppers__green__capsicum_spp__and_pimenta_spp__yield", 
    "chillies_and_peppers_yield", "citrus_fruit_yield", "cocoa_yield", 
    "coconuts_yield", "coffee_yield", "cow_peas_yield", "cranberries_yield", 
    "cucumbers_and_gherkins_yield", "currants_yield", "dates_yield", 
    "eggplants_yield", "figs_yield", "fonio_yield", "fruit_yield", "garlic_yield", 
    "ginger__raw_yield", "gooseberries_yield", "grapefruit_yield", "grapes_yield", 
    "green_maize_yield", "groundnut_yield", "hazelnuts_yield", "hempseed_yield", 
    "herbs__e_g__fennel__yield", "hop_cones_yield", "jojoba_seeds_yield", 
    "kiwi_yield", "kola_nuts_yield", "leeks_yield", "lemons_and_limes_yield", 
    "lentils_yield", "lettuce_yield", "linseed_yield", "locust_beans__carobs__yield", 
    "lupins_yield", "maize_yield", "mangoes_yield", "mate_leaves_yield", 
    "melon_yield", "melonseed_yield", "millet_yield", "mixed_grains_yield", 
    "mustard_seed_yield", "nutmeg__mace__cardamoms__raw_yield", "oats_yield", 
    "okra_yield", "olives_yield", "onions_and_shallots__green_yield", 
    "onions_yield", "orange_yield", "other_berries_and_fruits_of_the_genus_vaccinium_n_e_c__yield", 
    "other_citrus_fruit__n_e_c__yield", "other_fruits__n_e_c__yield", 
    "other_nuts__excluding_wild_edible_nuts_and_groundnuts__in_shell__n_e_c__yield",
    "other_oil_seeds__n_e_c__yield", "other_pome_fruits_yield", "other_pulses_n_e_c__yield", 
    "other_stimulant__spice_and_aromatic_crops__n_e_c__yield", "other_stone_fruits_yield", 
    "other_sugar_crops_n_e_c__yield", "other_tropical_fruits__n_e_c__yield", 
    "other_vegetables__fresh_n_e_c__yield", "oilpalm_yield", "papayas_yield", 
    "peaches_and_nectarines_yield", "pears_yield", "pea_yield", "peas__green_yield", 
    "pepper_yield", "peppermint__spearmint_yield", "persimmons_yield", 
    "pigeon_peas_yield", "pineapples_yield", "pistachios_yield", "plantains_yield", 
    "plums_yield", "poppy_seeds_yield", "potato_yield", "pulses_yield", 
    "pumpkins__squash_and_gourds_yield", "quinces_yield", "quinoa_yield", 
    "rapeseed_yield", "raspberries_yield", "rice_yield", "roots_and_tubers_yield", 
    "rye_yield", "safflower_seed_yield", "sesame_seed_yield", "sorghum_yield", 
    "sour_cherries_yield", "soybean_yield", "spinach_yield", "strawberries_yield", 
    "string_beans_yield", "sugarbeet_yield", "sugarcane_yield", "sugar_crops_yield", 
    "sunflower_yield", "sweet_potatoes_yield", "tallowtree_seeds_yield", 
    "tangerines_yield", "taro_yield", "tea_yield", "tobacco_yield", 
    "tomato_yield", "treenuts_yield", "triticale_yield", "vanilla__raw_yield", 
    "vegetables_yield", "vetches_yield", "walnuts_yield", "watermelons_yield", 
    "wheat_yield", "yams_yield", "yautia_yield"
]

# %%
crop_yields_csv = my_csv[crop_yields]
crop_yields_csv.to_csv('crop_yields_csv.csv')

# %%
fibre_crops_yields = [
    "abaca__manila_hemp__raw_yield", "agave_fibres__raw__n_e_c__yield", 
    "flax__raw_or_retted_yield", "fibre_crops__fibre_equivalent_yield", 
    "fibre_crops_yield", "jute_yield", "kapok_fruit_yield", 
    "kenaf__and_other_textile_bast_fibres__raw_or_retted_yield", 
    "ramie__raw_or_retted_yield", "sisal__raw_yield", "true_hemp__raw_or_retted_yield"
]

# %%
spices_aromatics_yields = [
    "cinnamon_and_cinnamon_tree_flowers__raw_yield", 
    "cloves__whole_stems__raw_yield", "ginger__raw_yield", 
    "nutmeg__mace__cardamoms__raw_yield", 
    "peppermint__spearmint_yield"
]

# %%
attainable_yields = [
    "barley_attainable_yield", "cassava_attainable_yield", 
    "cotton_attainable_yield", "groundnut_attainable_yield", 
    "maize_attainable_yield", "millet_attainable_yield", 
    "oilpalm_attainable_yield", "potato_attainable_yield", 
    "rapeseed_attainable_yield", "rice_attainable_yield", 
    "rye_attainable_yield", "sorghum_attainable_yield", 
    "soybean_attainable_yield", "sugarbeet_attainable_yield", 
    "sugarcane_attainable_yield", "sunflower_attainable_yield", 
    "wheat_attainable_yield"
]

# %%
yield_gaps = [
    "barley_yield_gap", "cassava_yield_gap", 
    "cotton_yield_gap", "groundnut_yield_gap", 
    "maize_yield_gap", "millet_yield_gap", 
    "oilpalm_yield_gap", "potato_yield_gap", 
    "rapeseed_yield_gap", "rice_yield_gap", 
    "rye_yield_gap", "sorghum_yield_gap", 
    "soybean_yield_gap", "sugarbeet_yield_gap", 
    "sugarcane_yield_gap", "sunflower_yield_gap", 
    "wheat_yield_gap"
]

# %%
oilcrops_yields = [
    "oilcrops__cake_equivalent_yield", "oilcrops__oil_equivalent_yield"
]
